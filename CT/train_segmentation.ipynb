# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/MyDrive/iss/PRS/PM/COVID-CT-Mask-Net-master')
# !ls
# Out:
# Mounted at /content/gdrive
# config_classifier.py	   models	      test_split_segmentation.txt
# config_segmentation.py	   plots	      train_classifier.py
# covid_data		   presentations      train_segmentation.py
# datasets		   pretrained_models  train_split_classification.txt
# eval_imgs		   __pycache__	      train_split_segmentation.txt
# evaluate_classifier.py	   README.md	      utils.py
# evaluation_mean_ap.py	   requirements.txt
# inference_segmentation.py  saved_models

# %%
# !python3 train_classifier.py --pretrained_segmentation_model segmentation_model.pth --backbone_name resnet34 --num_epochs 50 --save_every 10 --num_class 2 --truncation 1 --s_features 512 --roi_batch_size 128 --batch_size 8
# Out:
# Traceback (most recent call last):
#   File "train_classifier.py", line 199, in <module>
#     main(config_train, step)
#   File "train_classifier.py", line 71, in main
#     datapoint_covid_train_cl = dataset.COVID_CT_DATA(**dataset_covid_pars_train_cl)
#   File "/content/gdrive/My Drive/iss/PRS/PM/COVID-CT-Mask-Net-master/datasets/dataset_classifier.py", line 17, in __init__
#     self.fs = sorted(os.listdir(self.data))
# FileNotFoundError: [Errno 2] No such file or directory: '../covid_data/cncb/train_large'

# %%
# !python3 train_segmentation.py --num_epochs 100 --mask_type merge --save_every 10 --backbone_name resnet18 --truncation 1 --device cuda
# Out:
# cuda
# /usr/local/lib/python3.7/dist-packages/torchvision/ops/misc.py:22: FutureWarning: torchvision.ops.misc.Conv2d is deprecated and will be removed in future versions, use torch.nn.Conv2d instead.
#   "removed in future versions, use torch.nn.Conv2d instead.", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/torchvision/ops/misc.py:30: FutureWarning: torchvision.ops.misc.ConvTranspose2d is deprecated and will be removed in future versions, use torch.nn.ConvTranspose2d instead.
#   "removed in future versions, use torch.nn.ConvTranspose2d instead.", FutureWarning)
# 256
# COVIDMaskNet(
#   (transform): GeneralizedRCNNTransform()
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): BasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 30, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=[0, 1, 2, 3], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=128, bias=True)
#       (fc7): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=128, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=128, out_features=8, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign(featmap_names=[0, 1, 2, 3], output_size=(14, 14), sampling_ratio=2)
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(128, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# Start training, epoch = 0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 0: train loss = 1.098, validation loss = 0.740
# Epoch 1: train loss = 0.599, validation loss = 0.635
# Epoch 2: train loss = 0.521, validation loss = 0.596
# Epoch 3: train loss = 0.471, validation loss = 0.584
# Epoch 4: train loss = 0.432, validation loss = 0.564
# Epoch 5: train loss = 0.401, validation loss = 0.546
# Epoch 6: train loss = 0.374, validation loss = 0.556
# Epoch 7: train loss = 0.356, validation loss = 0.539
# Epoch 8: train loss = 0.342, validation loss = 0.539
# saved_models mrcnn_covid_segmentation_model_ckpt_10.pth
# Epoch 9: train loss = 0.328, validation loss = 0.552
# Epoch 10: train loss = 0.311, validation loss = 0.543
# Epoch 11: train loss = 0.296, validation loss = 0.558
# Epoch 12: train loss = 0.293, validation loss = 0.568
# Epoch 13: train loss = 0.281, validation loss = 0.555
# Epoch 14: train loss = 0.265, validation loss = 0.576
# Epoch 15: train loss = 0.261, validation loss = 0.589
# Epoch 16: train loss = 0.255, validation loss = 0.593
# Epoch 17: train loss = 0.252, validation loss = 0.589
# Epoch 18: train loss = 0.244, validation loss = 0.604
# saved_models mrcnn_covid_segmentation_model_ckpt_20.pth
# Epoch 19: train loss = 0.234, validation loss = 0.639
# Epoch 20: train loss = 0.225, validation loss = 0.659
# Epoch 21: train loss = 0.222, validation loss = 0.667
# Epoch 22: train loss = 0.220, validation loss = 0.669
# Epoch 23: train loss = 0.213, validation loss = 0.719
# Epoch 24: train loss = 0.209, validation loss = 0.716
# Epoch 25: train loss = 0.208, validation loss = 0.653
# Epoch 26: train loss = 0.203, validation loss = 0.662
# Epoch 27: train loss = 0.196, validation loss = 0.764
# Epoch 28: train loss = 0.194, validation loss = 0.716
# saved_models mrcnn_covid_segmentation_model_ckpt_30.pth
# Epoch 29: train loss = 0.190, validation loss = 0.707
# Epoch 30: train loss = 0.185, validation loss = 0.720
# Epoch 31: train loss = 0.182, validation loss = 0.692
# Epoch 32: train loss = 0.177, validation loss = 0.749
# Epoch 33: train loss = 0.178, validation loss = 0.682
# Epoch 34: train loss = 0.173, validation loss = 0.828
# Epoch 35: train loss = 0.171, validation loss = 0.740
# Epoch 36: train loss = 0.167, validation loss = 0.766
# Epoch 37: train loss = 0.166, validation loss = 0.840
# Epoch 38: train loss = 0.165, validation loss = 0.841
# saved_models mrcnn_covid_segmentation_model_ckpt_40.pth
# Epoch 39: train loss = 0.159, validation loss = 0.881
# Epoch 40: train loss = 0.158, validation loss = 0.901
# Epoch 41: train loss = 0.158, validation loss = 0.887
# Epoch 42: train loss = 0.157, validation loss = 0.834
# Epoch 43: train loss = 0.155, validation loss = 0.820
# Epoch 44: train loss = 0.154, validation loss = 0.832
# Epoch 45: train loss = 0.149, validation loss = 0.814
# Epoch 46: train loss = 0.151, validation loss = 0.835
# Epoch 47: train loss = 0.148, validation loss = 0.839
# Epoch 48: train loss = 0.146, validation loss = 0.859
# saved_models mrcnn_covid_segmentation_model_ckpt_50.pth
# Epoch 49: train loss = 0.147, validation loss = 0.855
# Epoch 50: train loss = 0.143, validation loss = 0.834
# Epoch 51: train loss = 0.143, validation loss = 0.898
# Epoch 52: train loss = 0.142, validation loss = 0.898
# Epoch 53: train loss = 0.142, validation loss = 0.905
# Epoch 54: train loss = 0.138, validation loss = 0.923
# Epoch 55: train loss = 0.137, validation loss = 0.876
# Epoch 56: train loss = 0.136, validation loss = 0.916
# Epoch 57: train loss = 0.138, validation loss = 0.938
# Epoch 58: train loss = 0.135, validation loss = 0.967
# saved_models mrcnn_covid_segmentation_model_ckpt_60.pth
# Epoch 59: train loss = 0.136, validation loss = 0.901
# Epoch 60: train loss = 0.137, validation loss = 0.883
# Epoch 61: train loss = 0.132, validation loss = 0.908
# Epoch 62: train loss = 0.132, validation loss = 0.986
# Epoch 63: train loss = 0.131, validation loss = 0.926
# Epoch 64: train loss = 0.127, validation loss = 1.021
# Epoch 65: train loss = 0.131, validation loss = 0.897
# Epoch 66: train loss = 0.133, validation loss = 0.909
# Epoch 67: train loss = 0.131, validation loss = 0.948
# Epoch 68: train loss = 0.126, validation loss = 0.905
# saved_models mrcnn_covid_segmentation_model_ckpt_70.pth
# Epoch 69: train loss = 0.125, validation loss = 0.982
# Epoch 70: train loss = 0.127, validation loss = 1.002
# Epoch 71: train loss = 0.125, validation loss = 0.962
# Epoch 72: train loss = 0.125, validation loss = 1.031
# Epoch 73: train loss = 0.125, validation loss = 1.032
# Epoch 74: train loss = 0.124, validation loss = 0.935
# Epoch 75: train loss = 0.121, validation loss = 1.069
# Epoch 76: train loss = 0.122, validation loss = 0.958
# Epoch 77: train loss = 0.124, validation loss = 1.027
# Epoch 78: train loss = 0.123, validation loss = 1.014
# saved_models mrcnn_covid_segmentation_model_ckpt_80.pth
# Epoch 79: train loss = 0.121, validation loss = 1.071
# Epoch 80: train loss = 0.121, validation loss = 0.967
# Epoch 81: train loss = 0.120, validation loss = 0.987
# Epoch 82: train loss = 0.120, validation loss = 1.042
# Epoch 83: train loss = 0.119, validation loss = 0.942
# Epoch 84: train loss = 0.119, validation loss = 0.990
# Epoch 85: train loss = 0.119, validation loss = 1.062
# Epoch 86: train loss = 0.118, validation loss = 1.038
# Epoch 87: train loss = 0.117, validation loss = 1.066
# Epoch 88: train loss = 0.116, validation loss = 0.987
# saved_models mrcnn_covid_segmentation_model_ckpt_90.pth
# Epoch 89: train loss = 0.116, validation loss = 1.054
# Epoch 90: train loss = 0.115, validation loss = 1.021
# Epoch 91: train loss = 0.115, validation loss = 0.959
# Epoch 92: train loss = 0.115, validation loss = 0.974
# Epoch 93: train loss = 0.115, validation loss = 1.035
# Epoch 94: train loss = 0.115, validation loss = 1.068
# Epoch 95: train loss = 0.116, validation loss = 1.018
# Epoch 96: train loss = 0.115, validation loss = 0.945
# Epoch 97: train loss = 0.115, validation loss = 1.026
# Epoch 98: train loss = 0.113, validation loss = 1.103
# saved_models mrcnn_covid_segmentation_model_ckpt_100.pth
# Epoch 99: train loss = 0.112, validation loss = 1.042
# Training took 7076.2 seconds
