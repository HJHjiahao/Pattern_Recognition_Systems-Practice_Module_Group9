# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/MyDrive/nus iss/prs-pm/COVID-CT-Mask-Net-master')
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# config_classifier.py	   models	      test_split_segmentation.txt
# config_segmentation.py	   plots	      train_classifier.py
# data_clean.ipynb	   presentations      train_segmentation.py
# datasets		   pretrained_models  train_split_classification.txt
# eval_imgs		   __pycache__	      train_split_segmentation.txt
# evaluate_classifier.py	   README.md	      Untitled0.ipynb
# evaluation_mean_ap.py	   requirements.txt   Untitled1.ipynb
# inference_segmentation.py  saved_models       utils.py

# %%
# !python3 train_classifier.py --pretrained_segmentation_model pretrained_models/lightweight_classifier_resnet34_t1.pth --backbone_name resnet34 --num_epochs 50 --save_every 10 --num_class 2 --truncation 1 --s_features 512 --roi_batch_size 128 --batch_size 8 --device cuda
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:671: SourceChangeWarning: source code of class 'torchvision.models.detection.anchor_utils.AnchorGenerator' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Loading parameter backbone.body.conv1.weight
# Loading parameter backbone.body.bn1.weight
# Loading parameter backbone.body.bn1.bias
# Loading parameter backbone.body.bn1.running_mean
# Loading parameter backbone.body.bn1.running_var
# Loading parameter backbone.body.bn1.num_batches_tracked
# Loading parameter backbone.body.layer1.0.conv1.weight
# Loading parameter backbone.body.layer1.0.bn1.weight
# Loading parameter backbone.body.layer1.0.bn1.bias
# Loading parameter backbone.body.layer1.0.bn1.running_mean
# Loading parameter backbone.body.layer1.0.bn1.running_var
# ...
